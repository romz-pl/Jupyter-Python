# %% [markdown]
# # Matplotlib presentation

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tck
import datetime

# %%
## The simplest

# %%
plt.plot(range(10))
plt.show()
